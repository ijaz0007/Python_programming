# %%
print("logic1")
print("logic2")

l1 : list[int] = [1,2,3]

try:
    print(5/2)
    print(l1[0])
    print(xyz) # error
except (ZeroDivisionError,IndexError,NameError):
    print("Zerro Division Error!")
print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 2.5
# 1
# Zerro Division Error!
# logic4
# logic5

# %%
print("logic1")
print("logic2")

l1 : list[int] = [1,2,3]
try:
    print(5/2)
    print(l1[0])# Error
    # print(xyz) # error
    open("aa.txt")
except (ZeroDivisionError):
    print("Zero Division Error")
except IndexError:
    print("Index Error")
except NameError:
    print("Name Error")
except:
    print("Something is wrong")

print("logic3")
print("logic4")
# Out:
# logic1
# logic2
# 2.5
# 1
# Something is wrong
# logic3
# logic4

# %%
l1 : list[int] = [1,2,3]
try:
    print(l1[200])
except Exception as e:
    print(f"something is wrong!\n {e}")
# Out:
# something is wrong!
#  list index out of range

# %%
class Student_Card():
    def __init__(self, roll_no : int, name : str, age : int) -> None:
        if age<18 or age>60:
            raise StudentAgeError("You are not eligible in this program!")
        self.roll_num = roll_no
        self.full_name = name
        self.full_age = age   
class StudentAgeError(Exception):
    pass
student1 = Student_Card(1,"Bashir Aziz",44)
print(student1.roll_num,student1.full_name,student1.full_age)
# Out:
# 1 Bashir Aziz 44

# %%
student2 = Student_Card(2,"Aftab",16) 
print(student2.roll_num,student2.full_name,student2.full_age)
# Out:
# ---------------------------------------------------------------------------
# StudentAgeError                           Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 student2 = Student_Card(2,"Aftab",16)
#       2 print(student2.roll_num,student2.full_name,student2.full_age)
#
# Cell In[89], line 4, in Student_Card.__init__(self, roll_no, name, age)
#       2 def __init__(self, roll_no : int, name : str, age : int) -> None:
#       3     if age<18 or age>60:
# ----> 4         raise StudentAgeError("You are not eligible in this program!")
#       5     self.roll_num = roll_no
#       6     self.full_name = name
#
# StudentAgeError: You are not eligible in this program!

# %% [markdown]
# # File Handling

# %% [markdown]
# https://www.geeksforgeeks.org/reading-writing-text-files-python/

# %% [markdown]
# <img src="https://camo.githubusercontent.com/ecb92506b9c9fc55686808598d6d9ccf2067e4e59cd33e54814db85b9d64902f/68747470733a2f2f6e65742d696e666f726d6174696f6e732e636f6d2f707974686f6e2f66696c652f696d672f6d6f6465732e706e67">

# %%
open("./abc.txt")
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
data = open("./abc.txt")
data
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
[i for i in dir(data)if "__"  not in i]
# Out:
# ['_CHUNK_SIZE',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
type(data)
# Out:
# _io.TextIOWrapper

# %%
from typing import TextIO

data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())
# Out:
# line 1
# line 2

# %%
from typing import TextIO

data:TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())

data.close() # close connectivity
# Out:
# line 1
# line 2

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.read())

print("Pakistan zinda bad!")
# Out:
# <class '_io.TextIOWrapper'>
# line1
# line2
# line3
# line4
# line5
# Pakistan zinda bad!

# %%
with open("./abc.txt") as file:
    print(file.readline())
    print(file.readline()) # behaves like generator function
# Out:
# line1
#
# line2

# %%
with open("./abc.txt") as file:
    print(file.readlines())
# Out:
# ['line1\n', 'line2\n', 'line3\n', 'line4\n', 'line5']

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.readline(), end="") # read only one line 
    print(file.readline(), end="")# line2
# Out:
# <class '_io.TextIOWrapper'>
# line1
# line2

# %%
with open("./abc.txt") as file:
    print(file.readlines()[:3])
# Out:
# ['line1\n', 'line2\n', 'line3\n']

# %%
with open("./abc.txt",'r') as file:
    print(file.read())
    print(file.write("pakistan zinnda bad"))
# Out:
# line1
# line2
# line3
# line4
# line5
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[33], line 3
#       1 with open("./abc.txt",'r') as file:
#       2     print(file.read())
# ----> 3     print(file.write("pakistan zinnda bad"))
#
# UnsupportedOperation: not writable

# %%
with open("./abc.txt",'w') as file:
    print(file.read())
    print(file.write("pakistan zinnda bad"))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[34], line 2
#       1 with open("./abc.txt",'w') as file:
# ----> 2     print(file.read())
#       3     print(file.write("pakistan zinnda bad"))
#
# UnsupportedOperation: not readable

# %%
with open("./abc1.txt", 'w') as file:  # type: TextIO
    file.write("Pakistan zinda bad")

# %%
with open("./abc1.txt", 'r+') as file:  # type: TextIO
    print(file.read())
    file.write("WE love our country!")
# Out:
# Pakistan zinda bad

# %%
with open("./abc1.txt", 'r+') as file:  # type: TextIO
    print(file.read())

    file.write("WE love our country!")

    print("After",file.read())
# Out:
# Pakistan zinda badWE love our country!
# After

# %%
with open('./abc1.txt','r+') as file:
    print(file.read())
    file.write("We love our country!")
    file.seek(0)        #The seek(0) method is used to move the file pointer back to the beginning of the file.
    print("after",file.read())
# Out:
# Pakistan zinda badWE love our country!WE love our country!We love our country!
# after Pakistan zinda badWE love our country!WE love our country!We love our country!We love our country!

# %% [markdown]
# # Now change modes

# %%
with open("./abc2.txt","r") as file:
    print(file.read())
# Out:
# PakistanPakistan

# %%
with open("./abc3.txt", 'a') as file:  # type: TextIO
    # print(file.read())
    file.write("Pakistan") 

# if file exist then it overwrite the text
# if file not exist then it will create new file

# %%
with open("./abc3.txt", 'a') as file:  # type: TextIO
    # print(file.read())
    file.write("line3") 

# if file not exist then it will create new file
# add content in last

# %%
with open("./abc.txt4", 'x') as file:  # type: TextIO
    # print(file.read())
    file.write("line3") 

# if file exist then it overwrite the text
# if file not exist then it will create new file

# %%
with open("./abc4.txt", 'x') as file:  # type: TextIO
    # print(file.read())
    file.write("line3") 


# if file not exist then it will create new file

# %%
with open("./abc4.txt", 'rb+') as file:  # type: TextIO
    print(file.read())
    # file.write("line3") 


# if file not exist then it will create new file
# Out:
# b'line3'

# %% [markdown]
# df:pd.Dataframe=pd.read_html(
# Mode	r	r+	w	w+	a	a+
# Read	+	+		+		+
# Write		+	+	+	+	+
# Create			+	+	+	+
# Cover			+	+
# Point in the beginning	+	+	+	+
# Point in the end					+	+)

# %% [markdown]
# # read some real world data files
# * image
# * csv
# * live camera

# %%
import pandas as pd

df : pd.DataFrame = pd.read_csv("./data.csv")

df
# Out:
#    id       name education
# 0   1    Sir Zia    Master
# 1   2   Sir Inam    Master
# 2   3  Sir Qasim    Master

# %%
df1 : pd.DataFrame = pd.read_excel("./demo.xlsx")
df1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ijaza\anaconda3\envs\python12\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\ijaza\anaconda3\envs\python12\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1318, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df1 : pd.DataFrame = pd.read_excel("./demo.xlsx")
#       2 df1
#
# File c:\Users\ijaza\anaconda3\envs\python12\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\ijaza\anaconda3\envs\python12\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File c:\Users\ijaza\anaconda3\envs\python12\Lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File c:\Users\ijaza\anaconda3\envs\python12\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp312-cp312-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      --------- --------------------------- 41.0/165.5 kB 991.0 kB/s eta 0:00:01
#      ----------------------------------- -- 153.6/165.5 kB 1.8 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/165.5 kB 1.8 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/165.5 kB 1.8 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/165.5 kB 1.8 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/165.5 kB 1.8 MB/s eta 0:00:01
#      ----------------------------------- -- 153.6/165.5 kB 1.8 MB/s eta 0:00:01
#      -----------------------------------  163.8/165.5 kB 427.9 kB/s eta 0:00:01
#      ------------------------------------ 165.5/165.5 kB 414.0 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ijaza\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ijaza\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ijaza\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.0 MB 2.6 MB/s eta 0:00:03
#     --------------------------------------- 0.1/8.0 MB 3.0 MB/s eta 0:00:03
#    - -------------------------------------- 0.2/8.0 MB 1.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/8.0 MB 1.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/8.0 MB 1.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/8.0 MB 1.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/8.0 MB 1.7 MB/s eta 0:00:05
#    --- ------------------------------------ 0.6/8.0 MB 1.7 MB/s eta 0:00:05
#    --- ------------------------------------ 0.7/8.0 MB 1.7 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/8.0 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/8.0 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.9/8.0 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/8.0 MB 1.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.1/8.0 MB 1.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.1/8.0 MB 1.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.2/8.0 MB 1.6 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.0 MB 1.6 MB/s eta 0:00:05
#    ------ --------------------------------- 1.4/8.0 MB 1.7 MB/s eta 0:00:04
#    ------- -------------------------------- 1.4/8.0 MB 1.6 MB/s eta 0:00:04
#    ------- -------------------------------- 1.5/8.0 MB 1.6 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.0 MB 1.6 MB/s eta 0:00:04
#    -------- ------------------------------- 1.7/8.0 MB 1.6 MB/s eta 0:00:04
#    -------- ------------------------------- 1.7/8.0 MB 1.6 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.0 MB 1.6 MB/s eta 0:00:04
#    --------- ------------------------------ 1.9/8.0 MB 1.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.0/8.0 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.0/8.0 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.0 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.2/8.0 MB 1.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.3/8.0 MB 1.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.3/8.0 MB 1.6 MB/s eta 0:00:04
#    ------------ --------------------------- 2.4/8.0 MB 1.6 MB/s eta 0:00:04
#    ------------ --------------------------- 2.5/8.0 MB 1.6 MB/s eta 0:00:04
#    ------------ --------------------------- 2.5/8.0 MB 1.6 MB/s eta 0:00:04
#    ------------- -------------------------- 2.6/8.0 MB 1.6 MB/s eta 0:00:04
#    ------------- -------------------------- 2.7/8.0 MB 1.6 MB/s eta 0:00:04
#    ------------- -------------------------- 2.7/8.0 MB 1.6 MB/s eta 0:00:04
#    ------------- -------------------------- 2.8/8.0 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.0 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.0 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 3.0/8.0 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 3.0/8.0 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 3.0/8.0 MB 1.6 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.0 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.0 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.0 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.2/8.0 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.3/8.0 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.3/8.0 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.4/8.0 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.5/8.0 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.6/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------- -------------------- 3.8/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------- -------------------- 4.0/8.0 MB 1.5 MB/s eta 0:00:03
#    -------------------- ------------------- 4.0/8.0 MB 1.5 MB/s eta 0:00:03
#    -------------------- ------------------- 4.1/8.0 MB 1.5 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.0 MB 1.5 MB/s eta 0:00:03
#    --------------------- ------------------ 4.3/8.0 MB 1.5 MB/s eta 0:00:03
#    --------------------- ------------------ 4.3/8.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.4/8.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.5/8.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.5/8.0 MB 1.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.6/8.0 MB 1.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/8.0 MB 1.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.8/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 4.8/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 4.9/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------------- -------------- 5.0/8.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------- -------------- 5.1/8.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.0 MB 1.5 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/8.0 MB 1.5 MB/s eta 0:00:02
#    -------------------------- ------------- 5.3/8.0 MB 1.5 MB/s eta 0:00:02
#    -------------------------- ------------- 5.4/8.0 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 5.4/8.0 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.0 MB 1.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.6/8.0 MB 1.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.7/8.0 MB 1.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.7/8.0 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.8/8.0 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.9/8.0 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 6.0/8.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 6.1/8.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 6.2/8.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.0 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 6.4/8.0 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 6.5/8.0 MB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.0 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/8.0 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.7/8.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.0/8.0 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/8.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/8.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.0 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 7.7/8.0 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.8/8.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  7.8/8.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 1.5 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    ------------------- -------------------- 92.2/189.9 kB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 174.1/189.9 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 189.9/189.9 kB 1.9 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.2 MB 2.2 MB/s eta 0:00:01
#    --- ------------------------------------ 0.2/2.2 MB 2.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.2 MB 1.8 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/2.2 MB 1.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.2 MB 1.8 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.2 MB 1.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.2 MB 1.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.2 MB 1.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.2 MB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 1.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.2 MB 1.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.2 MB 1.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 1.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 1.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 1.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.2 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 1.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 999.2 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 971.6 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 971.6 kB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 932.2 kB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 932.2 kB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 880.6 kB/s eta 0:00:01
#    ------------------------ --------------- 1.4/2.2 MB 867.1 kB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.2 MB 854.4 kB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.2 MB 832.9 kB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.2 MB 839.9 kB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 852.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 887.2 kB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.2 MB 914.4 kB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 929.4 kB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.2 MB 949.0 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.9/2.2 MB 947.2 kB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 960.5 kB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 970.8 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 980.5 kB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 985.3 kB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 990.1 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 976.9 kB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 3.1 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.6 MB 4.5 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/2.6 MB 2.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.6 MB 1.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.6 MB 1.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.6 MB 1.6 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.6 MB 1.6 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/2.6 MB 1.6 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.6 MB 1.5 MB/s eta 0:00:02
#    --------- ------------------------------ 0.6/2.6 MB 1.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.7/2.6 MB 1.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.7/2.6 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.6 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 0.9/2.6 MB 1.4 MB/s eta 0:00:02
#    -------------- ------------------------- 0.9/2.6 MB 1.4 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.6 MB 1.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.1/2.6 MB 1.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.1/2.6 MB 1.4 MB/s eta 0:00:02
#    ------------------ --------------------- 1.2/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.5/2.6 MB 1.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.9/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 2.0/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.6 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 2.3/2.6 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 1.1 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/103.2 kB ? eta -:--:--
#    --------------- ----------------------- 41.0/103.2 kB 667.8 kB/s eta 0:00:01
#    -------------------------------------- 103.2/103.2 kB 853.3 kB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("img1.jpeg")
plt.imshow(img)
plt.axis('off')  # Optional: to hide axis
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread("img1.jpeg")# covert into numpy array

plt.imshow(img)

# %%
from typing import List
import PyPDF2

def read_pdf(file_path: str) -> List[str]:
    with open(file_path, 'rb') as file:  # The 'b' in 'rb' stands for binary mode
        reader: PyPDF2.PdfReader = PyPDF2.PdfReader(file)
        text_content: List[str] = [page.extract_text() for page in reader.pages]
        return text_content

pages: list[str] = read_pdf("./mypdf.pdf")
pages
# Out:
# ['Pakistan  \nZinda  \nBad \n  ', 'We \nLove  \nOur \nCountry  \n  ', 'PIAIC ']

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/232.6 kB ? eta -:--:--
#    ---------- ----------------------------- 61.4/232.6 kB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 174.1/232.6 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 232.6/232.6 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
