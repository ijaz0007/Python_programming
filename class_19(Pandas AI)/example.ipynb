6 kB/s eta 0:00:02
#    --------------------------- ------------ 1.2/1.8 MB 463.1 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.3/1.8 MB 477.1 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 495.4 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 509.4 kB/s eta 0:00:01
#    -------------------------------- ------- 1.5/1.8 MB 519.2 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 531.7 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 544.4 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 556.8 kB/s eta 0:00:01
#    ------------------------------------- -- 1.7/1.8 MB 575.6 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 583.7 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 594.4 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 588.2 kB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-26.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from ast import Str
import pandas as pd
from pandas import DataFrame
from faker import Faker
import random
from datetime import datetime
import numpy as np
from typing import List, Dict, Union
from nptyping import NDArray


# Initialize Faker to generate synthetic data
fake = Faker()

# Define the data types for each data dictionary
TeachersDataType = Dict[str, List[Union[Str, int]]]
StudentsDataType = Dict[str, List]
FeesDataType = Dict[str, List]

# Generate Teachers table with static typing
teachers_data: TeachersDataType = {
    'Teacher_ID': [i for i in range(1, 11)],
    'Name': [fake.name() for _ in range(10)],
    'Subject': random.choices(['Math', 'Science', 'English', 'History', 'Geography'], k=10),
    'Email': [fake.email() for _ in range(10)]
}
teachers_df: DataFrame = pd.DataFrame(teachers_data)

# Generate Students table with static typing
students_data: StudentsDataType = {
    'Student_ID': [i for i in range(1, 51)],
    'Name': [fake.name() for _ in range(50)],
    'Age': [random.randint(5, 18) for _ in range(50)],
    'Grade': random.choices(['1st Grade', '2nd Grade', '3rd Grade', '4th Grade', '5th Grade'], k=50),
    'Teacher_ID': [random.randint(1, 10) for _ in range(50)]  # Assuming each student is assigned a teacher
}
students_df: DataFrame = pd.DataFrame(students_data)

# Generate Fees table with static typing
fees_data: FeesDataType = {
    'Payment_ID': [i for i in range(1, 51)],
    'Student_ID': [random.randint(1, 50) for _ in range(50)],
    'Amount': [random.uniform(100.0, 1000.0) for _ in range(50)],
    'Date_of_Payment': [fake.date_between(start_date='-1y', end_date='today') for _ in range(50)],
    'Status': random.choices(['Paid', 'Pending', 'Overdue'], k=50)
}
fees_df: DataFrame = pd.DataFrame(fees_data)

# Round the 'Amount' column in the fees table to 2 decimal places
fees_df['Amount'] = fees_df['Amount'].round(2)

# Print the dataframes with static types
print("Teachers Table:")
print(teachers_df)
print("\nStudents Table:")
print(students_df)
print("\nFees Table:")
print(fees_df)
# Out:
# C:\Users\ijaza\AppData\Local\Temp\ipykernel_18696\1294610354.py:1: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   from ast import Str
# Teachers Table:
#    Teacher_ID               Name    Subject                      Email
# 0           1      Audrey Chavez  Geography    mullenjesse@example.org
# 1           2        Brandi Kane       Math  territhompson@example.org
# 2           3         Richard Li    Science   edwinmendoza@example.net
# 3           4       Keith Wilson    History        erika70@example.net
# 4           5  Christopher Riley    Science       angela40@example.com
# 5           6        Cheryl Lane       Math  hernandezjohn@example.org
# 6           7      Gregory Jones  Geography     sararobles@example.net
# 7           8   Matthew Sullivan  Geography     nicholas56@example.org
# 8           9  Matthew Armstrong    History    berrynathan@example.org
# 9          10      Austin Dunlap       Math      carolyn86@example.org
#
# Students Table:
#     Student_ID                Name  Age      Grade  Teacher_ID
# 0            1       Mark Griffith   13  1st Grade          10
# 1            2      Rachael Miller    7  4th Grade           4
# 14          15          40  321.63      2024-04-25  Overdue
# 15          16          38  232.30      2024-02-13  Overdue
# 16          17           4  483.06      2023-12-14  Overdue
# 17          18          44  444.44      2023-08-27  Pending
# 18          19          14  520.25      2023-11-19  Pending
# 19          20          33  918.26      2023-12-21     Paid
# 20          21          35  133.58      2023-12-11  Pending
# 21          22           6  224.00      2023-09-03  Pending
# 22          23          18  133.00      2023-09-06  Overdue
# 23          24          34  487.21      2024-06-09  Pending
# 24          25          14  223.89      2024-01-04     Paid
# 25          26           7  468.73      2024-03-24  Pending
# 26          27          34  751.67      2024-02-04     Paid
# 27          28          44  903.60      2024-07-29  Pending
# 28          29          24  326.94      2024-07-28     Paid
# 29          30           9  142.91      2024-02-07  Pending
# 30          31          21  697.40      2024-01-02  Overdue
# 31          32          41  340.27      2024-07-18  Overdue
# 32          33          35  539.76      2024-05-17  Pending
# 33          34           4  851.75      2023-10-23  Pending
# 34          35          18  231.29      2023-11-04     Paid
# 35          36          38  419.95      2024-05-04     Paid
# 36          37          50  493.97      2023-09-03  Pending
# 37          38          38  344.89      2023-08-07  Pending
# 38          39          42  903.73      2023-08-30  Pending
# 39          40          15  810.60      2024-08-04     Paid
# 40          41          33  865.32      2023-10-22  Pending
# 41          42          44  237.70      2024-07-17  Overdue
# 42          43          49  955.27      2023-09-24     Paid
# 43          44           5  851.08      2024-04-09  Overdue
# 44          45          41  997.34      2024-03-10     Paid
# 45          46          15  550.64      2023-12-08     Paid
# 46          47          10  416.65      2024-03-06     Paid
# 47          48          20  102.16      2024-04-10  Pending
# 48          49          43  348.37      2023-11-08  Overdue
# 49          50          14  139.15      2023-09-22     Paid

# %%
import pandas as pd
import pandera as pa

# Define a schema for the DataFrame
schema = pa.DataFrameSchema({
    "A": pa.Column(pa.Int),
    "B": pa.Column(pa.Int),
})

# Create a Pandas DataFrame
data : pd.DataFrame = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Validate the DataFrame against the schema
schema.validate(data)

# Perform the summation using Pandera
total_sum = data.sum().sum()

print(total_sum)
# Out:
# 21

# %%
# !pip install pandera
# Out:
# Requirement already satisfied: pandera in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (0.20.3)
# Requirement already satisfied: multimethod<=1.10.0 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandera) (1.10)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandera) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ijaza\appdata\roaming\python\python312\site-packages (from pandera) (24.1)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandera) (2.2.2)
# Requirement already satisfied: pydantic in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandera) (2.7.4)
# Requirement already satisfied: typeguard in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandera) (4.3.0)
# Requirement already satisfied: typing-inspect>=0.6.0 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandera) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandera) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ijaza\appdata\roaming\python\python312\site-packages (from pandas>=1.2.0->pandera) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandas>=1.2.0->pandera) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pandas>=1.2.0->pandera) (2024.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from typing-inspect>=0.6.0->pandera) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from typing-inspect>=0.6.0->pandera) (4.12.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pydantic->pandera) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\ijaza\anaconda3\envs\python12\lib\site-packages (from pydantic->pandera) (2.18.4)
# Requirement already satisfied: six>=1.5 in c:\users\ijaza\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pandera) (1.16.0)

# %%
# %pip install nptypingpandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement nptypingpandas (from versions: none)
# ERROR: No matching distribution found for nptypingpandas
